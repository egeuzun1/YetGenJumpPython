# %% [markdown]
# # Problem 1
# Sözlükleri kullanarak bir telefon rehberi yazın. Bu rehberde kullanıcıya kimin telefonunu görüntülemek istediğini sorun ve kullanıcının girdiği isme göre o kişinin telefon numarasını yazdırın. Proje sonunda elde edeceğiniz çıktı  şuna benzer olmalı:
#
#
# Lütfen numarasını öğrenmek istediğiniz kişinin adını girin: Ahmet
#
# Ahmet isimli kişinin numarası şu şekildedir: 0532 678 13 19

# %%
# 1.Problemin Çözümünü Buraya Yazınız
dict = {
    "Kadriye" : "0542 346 75 22",
    "Mualla" : "0537 486 59 28",
    "Kaya" : "0574 873 42 88",
    "Naci" : "0531 734 62 47",
    "Gül" : "0552 753 89 92",
    "Ayşegül" : "0532 467 12 00",
    "Lalesu" : "0565 567 22 44",
}

name=input("Lütfen numarasını öğrenmek istediğiniz kişinin adını girin: \n").capitalize()
print(name, "isimli kişinin numarası şu şekildedir:", dict[name])
# Out:
# Mualla isimli kişinin numarası şu şekildedir: 0537 486 59 28

# %% [markdown]
# # Problem 2
# Sözlükleri kullanarak bir şirket çalışanları indeksi oluşturun. Bu isim indeksinde kişilerin isimleri key, kişilerin  memleket, yaş ve görev bilgileri value olmalıdır. Burada kullanacağımız value değerleri liste olmalıdır.
#
#
# Daha sonra bir isim sorgulama ekranı gibi kullanıcıya kimin bilgilerini görüntülemek istediğini
# sorun ve sorgulanan kişinin ekranda gösterilmesini sağlayın. Proje sonunda elde edeceğiniz çıktı şu şekilde olmalı:
#
#
# Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: Mehmet Yağız
#
# Mehmet Yağız= Memleket: Adana Yaş: 40 Görev: Direktör

# %%
# 2.Problemin Çözümünü Buraya Yazınız
dict= {
    "Tahsin Pala" : ["Antalya", "37", "Yazılımcı"],
    "Nur Güzelcan" : ["Yalova", "34", "Tasarım Sorumlusu"],
    "Ekin Fidanbaş" : ["İzmir", "29", "İnsan Kaynakları Uzmanı"],
    "Mahir Nallı" : ["Edirne", "22", "Yönetim Kurulu Başkanı"],
    "Mehmet Yağız" : ["Adana", "40", "Direktör"],
    "Sugül Paşasu" : ["Isparta", "32", "Müşteri Temsilcisi"]
}

name=input("Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: \n").title()
print(name + "=" + " Memleket: " + dict[name][0] + " Yaş: " + dict[name][1] + " Görev: " + dict[name][2])
# Out:
# Tahsin Pala= Memleket: Antalya Yaş: 37 Görev: Yazılımcı

# %% [markdown]
# # Problem 3
#
# 3 öğrenciden oluşan bir öğrenci not sözlüğü oluşturun. Bu sözlükte öğrencilerin notları value olarak bir listede toplansın.
#
# Kullanıcıya hangi öğrencinin notlarını görmek istediğini sorun. Öğrencinin notu görüntülendiğinde program sonunda şöyle bir çıktı elde etmelisiniz:
#
# ```
# Lütfen notlarını görmek istediğiniz öğrencinin adını girin: Mehmet
#
# Mehmet isimli öğrencinin      1.Sınav Notu:72
#                               2.Sınav Notu:66
#                               3.Sınav Notu:48
# Not Ortalaması: 62.0

# %%
# 3.Problemin Çözümünü Buraya Yazınız
dict= {
    "Mehmet" : [72, 66, 48],
    "Ali" : [97, 82, 93],
    "Veli" : [56, 64, 78]
}

name=input("Lütfen notlarını görmek istediğiniz öğrencinin adını girin: \n").capitalize()
if not(name in dict):
    print("Böyle bir öğrenci bulunmamaktadır.")
else:
    lenName=len(f"{name} isimli öğrencinin")
    neededSpaceNum= 32-lenName #32 because 1 tab equals 8 spaces in here, thus 4 \t makes 32 spaces
    neededSpaceStr=""
    for i in range(neededSpaceNum):
      neededSpaceStr=neededSpaceStr+" "
    print(f"{name} isimli öğrencinin{neededSpaceStr}1. Sınav Notu:{dict[name][0]}\n\t\t\t\t2. Sınav Notu:{dict[name][1]}"
        f"\n\t\t\t\t3. Sınav Notu:{dict[name][2]}")
    print(f"Not Ortalaması: {round((dict[name][0]+dict[name][1]+dict[name][2])/3,2)}")
# Out:
# Mehmet isimli öğrencinin        1. Sınav Notu:72
# 				2. Sınav Notu:66
# 				3. Sınav Notu:48
# Not Ortalaması: 62.0

# %% [markdown]
# # Problem 4

# %%
# 1-  "Bmw, Mercedes, Opel, Mazda" elemanlarına sahip bir liste oluşturunuz.
list=["Bmw","Mercedes","Opel","Mazda"]
print(list)
# 2-  Liste Kaç elemanlıdır ?
print(len(list))
# 3-  Listenin ilk ve son elemanı nedir ?
print("İlk eleman:",list[0])
print("Son eleman:",list[-1])
# 4-  Mazda değerini Toyota ile değiştirin.
list[3]="Toyota"
print(list)
# 5-  Listenin -2 indeksindeki değer nedir ?
print(list[-2])
# 6-  Listenin ilk 3 elemanını alın.
print(list[0:3])
# 7-  Listenin son 2 elemanı yerine "Toyota" ve "Renault" değerlerini ekleyin.
list[-2]="Toyota"
list[-1]="Renault"
print(list)
# 8-  Listenin üzerine "Audi" ve "Nissan" değerlerini ekleyin.
list.append("Audi")
list.append("Nissan")
print(list)
# 9- Listenin son elemanını silin.
list.pop()
print(list)
# 10- Liste elemanlarını tersten yazdırınız.
list.reverse()
print(list)
print()
# 11- Aşağıdaki verileri bir liste içinde saklayınız. 
list2=[["Yiğit Bilgi 2010", (70,60,70)],
       ["Sena Turan  1999", (80,80,70)],
       ["Ahmet Turan 1998", (80,70,90)]]
      # studentA: Yiğit Bilgi 2010, (70,60,70)
      # studentB: Sena Turan  1999, (80,80,70)
      # studentC: Ahmet Turan 1998, (80,70,90) 
print(list2)
# 12- Liste elemanlarını ekrana yazdırınız.
print(list2[0])
print(list2[1])
print(list2[2])
print()
  
names = ['Ali','Yağmur','Hakan','Deniz']
years = [1998, 2000, 1998, 1987]

# 13-  "Cenk" ismini listenin sonuna ekleyiniz.
names.append("Cenk")
# 14-  "Sena" değerini listenin başına ekleyiniz.
names.insert(0,"Sena")
# 15-  "Deniz" ismini listeden siliniz.
names.remove("Deniz")
print(names)
# 16-  "Ali" listenin bir elemanı mıdır ?
if "Ali" in names:
    print("Ali bu listenin bir elemanıdır.")
else:
    print("Ali bu listenin bir elemanı değildir.")
# 17-  Liste elemanlarını ters çevirin.
names.reverse()
print(names)
# 18-  Liste elemanlarını alfabetik olarak sıralayınız.
names.sort()
print(names)
print()

# 19-  years listesini rakamsal büyüklüğe göre sıralayınız.
years.sort()
print(years)
print()
# 20-  str = "Chevrolet,Dacia" karakter dizisini listeye çeviriniz.
str=["Chevrolet","Dacia"]
print(str)
print("str değişkeninin türü: ", type(str))
print()
# 21- years dizisinde kaç tane 1998 değeri vardır ?
num=years.count(1998)
print(f"years listesinde {num} tane 1998 değeri bulunur.")
# 22- years dizisinin tüm elemanlarını siliniz.
years.clear()
print("years =",years)
print()
# 23- Kullanıcıdan alacağınız 3 tane marka bilgisini bir listede saklayınız.
brand1=input("İlk markayı giriniz: \n")
brand2=input("İkinci markayı giriniz: \n")
brand3=input("Üçüncü markayı giriniz: \n")

brandList=[brand1,brand2,brand3]
print(brandList)
# Out:
# ['Bmw', 'Mercedes', 'Opel', 'Mazda']
# 4
# İlk eleman: Bmw
# Son eleman: Mazda
# ['Bmw', 'Mercedes', 'Opel', 'Toyota']
# Opel
# ['Bmw', 'Mercedes', 'Opel']
# ['Bmw', 'Mercedes', 'Toyota', 'Renault']
# ['Bmw', 'Mercedes', 'Toyota', 'Renault', 'Audi', 'Nissan']
# ['Bmw', 'Mercedes', 'Toyota', 'Renault', 'Audi']
# ['Audi', 'Renault', 'Toyota', 'Mercedes', 'Bmw']
#
# [['Yiğit Bilgi 2010', (70, 60, 70)], ['Sena Turan  1999', (80, 80, 70)], ['Ahmet Turan 1998', (80, 70, 90)]]
# ['Yiğit Bilgi 2010', (70, 60, 70)]
# ['Sena Turan  1999', (80, 80, 70)]
# ['Ahmet Turan 1998', (80, 70, 90)]
#
# ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Cenk']
# Ali bu listenin bir elemanıdır.
# ['Cenk', 'Hakan', 'Yağmur', 'Ali', 'Sena']
# ['Ali', 'Cenk', 'Hakan', 'Sena', 'Yağmur']
#
# [1987, 1998, 1998, 2000]
#
# ['Chevrolet', 'Dacia']
# str değişkeninin türü:  <class 'list'>
#
# years listesinde 2 tane 1998 değeri bulunur.
# years = []
#
# ['A', 'B', 'C']
