# %% [markdown]
# # Problem 1
# Kullanıcıdan aldığı ürün bilgisini (ad, fiyat) urunler.txt dosyasına kayıt eden fonksiyonu yazınız.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
def newProduct(name,price):
    with open("urunler.txt","a+") as file:
        product=f"({name},{price})"
        file.write(f"\n{product}")
        file.seek(0)
        content=file.read()
        print(f"Ürünler:{content}")
newProduct(input("Ürünün ismini giriniz: \n"),input("Ürünün fiyatını(TL) giriniz: \n"))
# Out:
# Ürünler:
# (Süt,45)
# (Fettucine Makarna,75)
# (Toz Parmesan,175)
# (Pesto Sos,60)
# (Sarımsak(Kg),40)

# %% [markdown]
# # Problem 2
# 1.problemde oluşturulan text dosyası içerisinde kullanıcıdan alacağımız eski kelime isimli değişkene atadığımız
# ve değiştirilmesini istediğimiz kelimemizi yerini alıcak olan yeni kelime isimli değişkene atayın. Belirlenen kelimeleri text dosyasında değiştiren fonksiyonu yazınız.

# %%
# 2.Problemin Çözümünü Buraya Yazınız
def changeProduct(eskiKelime,yeniKelime):
    with open("urunler.txt","r+") as file:
        content=file.read()
        newContent=content.replace(eskiKelime,yeniKelime)
    with open("urunler.txt","w+") as file:
        file.write(newContent)
    with open("urunler.txt","r+") as file:
        read=file.read()
        print(f"Yeni Ürünler:{read}")
changeProduct(input("Değiştirmek istediğiniz kelimeyi girin: \n"),input("Yeni kelimeyi girin: \n"))
# Out:
# Yeni Ürünler:
# (Günlük Süt,45)
# (Tagliatelle Makarna,75)
# (Toz Parmesan,175)
# (Pesto Sos,60)
# (Sarımsak(Kg),40)

# %% [markdown]
# # Problem 3
# Vehicle sınıfının tüm değişkenlerini ve yöntemlerini devralacak bir alt sınıf olarak Bus sınıfı oluşturunuz.
#
#
#
# ```
# Output
# > Name: School Volvo Speed: 180 Mileage: 12
# ```

# %%
# 3.Problemin Çözümünü Buraya Yazınız
class Vehicle():
    def __init__(self,name,speed,mileage):
        self.name=name
        self.speed=speed
        self.mileage=mileage
    def info(self):
        print(f"Name: {self.name} Speed: {self.speed} Mileage: {self.mileage}")
araç1=Vehicle("Audi","190","25")
araç1.info()
print()

class Bus(Vehicle):
    pass
araç2=Bus("School Volvo","180","12")
araç2.info()
# Out:
# Name: Audi Speed: 190 Mileage: 25
#
# Name: School Volvo Speed: 180 Mileage: 12
