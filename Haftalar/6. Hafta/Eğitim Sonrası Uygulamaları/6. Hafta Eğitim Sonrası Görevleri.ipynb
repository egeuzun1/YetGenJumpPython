# %% [markdown]
# # Problem 1
# Bir sayının çift olup olmadığını sorgulayan bir fonksiyon yazın. Bu fonksiyon, eğer sayı çift ise bu değeri dönsün. Ancak sayı tek sayı ise fonksiyon raise ile ValueError hatası oluştursun. Daha sonra, içinde çift ve tek sayılar bulunduran bir liste tanımlayın ve liste üzerinde gezinerek ekrana sadece çift sayıları bastırın.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
def isEven(x):
    if x % 2==0:
        return x
    else:
        raise ValueError
list=[1,2,3,4,5,6,45,32,98,63,44,23,124,1002]

for i in range(len(list)):
    try:
        isEven(list[i])
        print(list[i])
    except ValueError:
        continue
# Out:
# 2
# 4
# 6
# 32
# 98
# 44
# 124
# 1002

# %% [markdown]
# # Problem 2
#
# 2 YetGen lideri ders sırasında canları sıkılınca oyun oynamak isterler. Ancak hangi oyunu oynayacaklarına karar veremezler ve son olarak kendi oyunlarını yazmaya karar verirler.
# Liderlerimizin kodlamak istediği oyun kuralları şöyledir:
# - Oyunda random olarak 0 ile 100 arasında bir sayı tutulur.
# - Kullanıcıdan bilgisayarın tuttuğu sayıyı tahmin etmesi için bir sayı girmesini istenir.
# - Eğer kullanıcının girdiği sayı bulunması gereken sayıdan küçükse  tahmininizi yükseltin, büyükse tahmininizi düşürün şeklinde bir çıktı verilir.
# - Oyunun gerçeğe yakın olması için bilgisayarın çalışmasını simgelemek için 1 saniye bekleme süresi tanınır.
# - Kullanıcı 5 hakkı vardır. 5 hakkı da kullanıp sayıyı bulamazsa oyunu kaybeder.

# %%
# 2.Problemin Çözümünü Buraya Yazınız
from random import *
from time import *
number=randint(1,100)
print("Welcome to the NumberGuesser, I have a number on my mind between 1 and 100 (both included).")
print("You will have 5 chances to guess my number and I will say whether it is greater or smaller than my number.")
print("So, Let's Start!")
chance=5
while True:
    guess=input("Enter your guess: ")
    '''while guess.isdigit() == False:
        guess=input("Error! Please enter a number: \n")'''
    try:
        guess = int(guess)
    except Exception:
        guess=input(f"Error! Please enter a number: \n")
        guess = int(guess)
    print(f"Your guess: {guess}")
    sleep(1)
    if guess < number:
        print(f"My number is greater than {guess}")
    elif guess > number:
        print(f"My number is smaller than {guess}")
    elif guess==number:
        print(f"Congratulations, You Won, My Number Was {guess}!")
        break
    chance -= 1
    if chance==0:
        print(f"You are out of chances, sorry, my number was {number}")
        break
# Out:
# Welcome to the NumberGuesser, I have a number on my mind between 1 and 100 (both included).
# You will have 5 chances to guess my number and I will say whether it is greater or smaller than my number.
# So, Let's Start!
# Your guess: 63
# My number is greater than 63
# Your guess: 82
# My number is smaller than 82
# Your guess: 73
# My number is greater than 73
# Your guess: 77
# My number is smaller than 77
# Your guess: 74
# Congratulations, You Won, My Number Was 74!
